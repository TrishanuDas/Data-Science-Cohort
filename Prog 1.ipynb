# %%
lis = ["a","b","c","d","e"]
lis2 = ["f","g","h","i"]
print(lis)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
lis.pop()
print(lis)
# Out:
# ['a', 'b', 'c', 'd']

# %%
lis.insert(1,"p")
print(lis)
# Out:
# ['a', 'p', 'b', 'c', 'd']

# %%
lis.remove("p")
print(lis)
# Out:
# ['a', 'b', 'c', 'd']

# %%
print(len(lis))
# Out:
# 4

# %%
lis.clear()
print(lis)
# Out:
# []
